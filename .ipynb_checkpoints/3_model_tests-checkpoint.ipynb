# %% [markdown]
# # LSTM Model Test
#
# Long short-term memory is a recurrent neural network used to model sequential data. For this specific use, we wanted a model that would be able to analyze patterns and trends for a given stock data.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import sklearn.preprocessing
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import StandardScaler


from tensorflow.keras import models
from tensorflow.keras.layers import LSTM,Dense

# %%
df_prices = pd.read_csv('./data/prices-split-adjusted.csv')
df_prices.fillna(float(0))
df_prices['date'] = pd.to_datetime(df_prices['date'])

df_prices = df_prices[df_prices['symbol']=='XOM']
df_prices = df_prices.drop(columns=['symbol'])
df_dates = df_prices['date'].copy()
df_prices = df_prices.set_index('date')

df = df_prices['close'].to_frame()

df.head()
# Out:
#                 close
# date
# 2010-01-04  69.150002
# 2010-01-05  69.419998
# 2010-01-06  70.019997
# 2010-01-07  69.800003
# 2010-01-08  69.519997

# %%
def prep_data(df, scaler, split):
    df = scaler.fit_transform(np.array(df).reshape(-1,1))
    size = int(len(df)*split)

    train_data = df[0:size,:]
    test_data = df[size:,:]
    
    return train_data, test_data

def fix_data(data, scaler):
    return scaler.inverse_transform(np.array(data).reshape(-1,1))

def build_data(data, step):
    x, y = [], []
    
    for i in range(len(data)-step-1):
        x.append(data[i:(i+step),0])
        y.append(data[i+step,0])
        
    return np.array(x), np.array(y)


def build_model(optimizer, step):
    model = models.Sequential()

    model.add(LSTM(64,return_sequences=True,input_shape=(step,1)))
    model.add(LSTM(50,return_sequences=True))
    model.add(LSTM(32,return_sequences=True))
    model.add(LSTM(50,return_sequences=False))
    model.add(Dense(1))
    model.compile(optimizer=optimizer,loss='mean_squared_error')
    model.summary()
    
    return model

# %%
split = 0.7
step = 60

standard = StandardScaler()
min_max = sklearn.preprocessing.MinMaxScaler()

scaler = min_max

train_data, test_data = prep_data(df, scaler, split)

X_train, y_train = build_data(train_data, step)
X_test, y_test = build_data(test_data, step)

print("X Training Shape: "+str(X_train.shape))
print("X Test Shape: "+str(X_test.shape))
print("Y Training Shape: "+str(y_train.shape))
print("Y Test Shape: "+str(y_test.shape))

X_train = np.reshape(X_train,(X_train.shape[0],X_train.shape[1],1))
X_test = X_test.reshape(X_test.shape[0],X_test.shape[1],1)
# Out:
# X Training Shape: (1172, 60)
# X Test Shape: (468, 60)
# Y Training Shape: (1172,)
# Y Test Shape: (468,)

# %%
model = build_model('adam',step)
# Out:
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_16 (LSTM)               (None, 60, 64)            16896
# _________________________________________________________________
# lstm_17 (LSTM)               (None, 60, 50)            23000
# _________________________________________________________________
# lstm_18 (LSTM)               (None, 60, 32)            10624
# _________________________________________________________________
# lstm_19 (LSTM)               (None, 50)                16600
# _________________________________________________________________
# dense_4 (Dense)              (None, 1)                 51
# =================================================================
# Total params: 67,171
# Trainable params: 67,171
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(X_train,y_train,epochs=200,batch_size=50)

y_hat = model.predict(X_test)

error = np.sqrt(mean_squared_error(y_test,y_hat))

y_test = fix_data(y_test, scaler)
y_hat = fix_data(y_hat, scaler)

error
# Out:
# Epoch 1/200
# 24/24 [==============================] - 3s 108ms/step - loss: 0.0807
# Epoch 2/200
# 24/24 [==============================] - 3s 107ms/step - loss: 0.0091
# Epoch 3/200
# 24/24 [==============================] - 3s 106ms/step - loss: 0.0043
# Epoch 4/200
# 24/24 [==============================] - 3s 106ms/step - loss: 0.0038
# Epoch 5/200
# 24/24 [==============================] - 3s 106ms/step - loss: 0.0038
# Epoch 6/200
# 24/24 [==============================] - 3s 106ms/step - loss: 0.0037
# Epoch 7/200
# 24/24 [==============================] - 3s 106ms/step - loss: 0.0037
# Epoch 8/200
# 24/24 [==============================] - 3s 108ms/step - loss: 0.0033
# Epoch 9/200
# 24/24 [==============================] - 3s 107ms/step - loss: 0.0037
# Epoch 10/200
# 24/24 [==============================] - 3s 107ms/step - loss: 0.0035
# Epoch 11/200
# 24/24 [==============================] - 3s 108ms/step - loss: 0.0031
# Epoch 12/200
# 24/24 [==============================] - 3s 109ms/step - loss: 0.0031
# Epoch 13/200
# 24/24 [==============================] - 3s 108ms/step - loss: 0.0029
# Epoch 14/200
# 24/24 [==============================] - 3s 108ms/step - loss: 0.0028
# Epoch 15/200
# 24/24 [==============================] - 3s 108ms/step - loss: 0.0030
# Epoch 16/200
# 24/24 [==============================] - 3s 109ms/step - loss: 0.0027
# Epoch 17/200
# 24/24 [==============================] - 3s 111ms/step - loss: 0.0027
# Epoch 18/200
# 24/24 [==============================] - 3s 109ms/step - loss: 0.0027
# Epoch 19/200
# 24/24 [==============================] - 3s 109ms/step - loss: 0.0024
# Epoch 20/200
# 24/24 [==============================] - 3s 110ms/step - loss: 0.0023
# Epoch 21/200
# 24/24 [==============================] - 3s 110ms/step - loss: 0.0024
# Epoch 22/200
# 24/24 [==============================] - 3s 110ms/step - loss: 0.0023
# Epoch 23/200
# 24/24 [==============================] - 3s 110ms/step - loss: 0.0021
# Epoch 24/200
# 24/24 [==============================] - 3s 112ms/step - loss: 0.0021
# Epoch 25/200
# 24/24 [==============================] - 3s 110ms/step - loss: 0.0020
# Epoch 26/200
# 24/24 [==============================] - 3s 110ms/step - loss: 0.0018
# Epoch 27/200
# 24/24 [==============================] - 3s 109ms/step - loss: 0.0017
# Epoch 28/200
# 24/24 [==============================] - 3s 109ms/step - loss: 0.0018
# Epoch 29/200
# 24/24 [==============================] - 3s 110ms/step - loss: 0.0019
# Epoch 30/200
# 24/24 [==============================] - 3s 109ms/step - loss: 0.0016
# Epoch 31/200
# 24/24 [==============================] - 3s 110ms/step - loss: 0.0016
# Epoch 32/200
# 24/24 [==============================] - 3s 109ms/step - loss: 0.0015
# Epoch 33/200
# 24/24 [==============================] - 3s 109ms/step - loss: 0.0016
# Epoch 34/200
# 24/24 [==============================] - 3s 111ms/step - loss: 0.0015
# Epoch 35/200
# 24/24 [==============================] - 3s 110ms/step - loss: 0.0015
# Epoch 36/200
# 24/24 [==============================] - 3s 109ms/step - loss: 0.0015
# Epoch 37/200
# 24/24 [==============================] - 3s 120ms/step - loss: 0.0016
# Epoch 38/200
# 24/24 [==============================] - 3s 116ms/step - loss: 0.0015
# Epoch 39/200
# 24/24 [==============================] - 3s 109ms/step - loss: 0.0014
# Epoch 40/200
# 24/24 [==============================] - 3s 110ms/step - loss: 0.0013
# Epoch 41/200
# 24/24 [==============================] - 3s 110ms/step - loss: 0.0013
# Epoch 42/200
# 24/24 [==============================] - 3s 111ms/step - loss: 0.0014
# Epoch 43/200
# 24/24 [==============================] - 3s 110ms/step - loss: 0.0012
# Epoch 44/200
# 24/24 [==============================] - 3s 109ms/step - loss: 0.0014
# Epoch 45/200
# 24/24 [==============================] - 3s 110ms/step - loss: 0.0013
# Epoch 46/200
# 24/24 [==============================] - 3s 110ms/step - loss: 0.0012
# Epoch 47/200
# 24/24 [==============================] - 3s 109ms/step - loss: 0.0011
# Epoch 48/200
# 24/24 [==============================] - 3s 109ms/step - loss: 0.0014
# Epoch 49/200
# 24/24 [==============================] - 3s 109ms/step - loss: 0.0014
# Epoch 50/200
# 24/24 [==============================] - 3s 110ms/step - loss: 0.0012
# Epoch 51/200
# 24/24 [==============================] - 3s 109ms/step - loss: 9.9698e-04
# Epoch 52/200
# 24/24 [==============================] - 3s 110ms/step - loss: 9.5951e-04
# Epoch 53/200
# 24/24 [==============================] - 3s 109ms/step - loss: 0.0010
# Epoch 54/200
# 24/24 [==============================] - 3s 109ms/step - loss: 9.1534e-04
# Epoch 55/200
# 24/24 [==============================] - 3s 110ms/step - loss: 9.0427e-04
# Epoch 56/200
# 24/24 [==============================] - 3s 109ms/step - loss: 0.0010
# Epoch 57/200
# 24/24 [==============================] - 3s 113ms/step - loss: 8.8869e-04
# Epoch 58/200
# 24/24 [==============================] - 3s 111ms/step - loss: 9.7142e-04
# Epoch 59/200
# 24/24 [==============================] - 3s 110ms/step - loss: 9.2965e-04
# Epoch 60/200
# 24/24 [==============================] - 3s 126ms/step - loss: 8.7278e-04
# Epoch 61/200
# 24/24 [==============================] - 3s 112ms/step - loss: 0.0011
# Epoch 62/200
# 24/24 [==============================] - 3s 115ms/step - loss: 0.0011
# Epoch 63/200
# 24/24 [==============================] - 3s 122ms/step - loss: 9.4029e-04
# Epoch 64/200
# 24/24 [==============================] - 3s 120ms/step - loss: 7.8563e-04
# Epoch 65/200
# 24/24 [==============================] - 3s 108ms/step - loss: 7.4159e-04
# Epoch 66/200
# 24/24 [==============================] - 3s 108ms/step - loss: 7.9306e-04
# Epoch 67/200
# 24/24 [==============================] - 3s 109ms/step - loss: 8.3272e-04
# Epoch 68/200
# 24/24 [==============================] - 3s 109ms/step - loss: 9.9152e-04
# Epoch 69/200
# 24/24 [==============================] - 3s 108ms/step - loss: 7.6069e-04
# Epoch 70/200
# 24/24 [==============================] - 3s 109ms/step - loss: 6.6446e-04
# Epoch 71/200
# 24/24 [==============================] - 3s 108ms/step - loss: 7.5002e-04
# Epoch 72/200
# 24/24 [==============================] - 3s 108ms/step - loss: 8.5003e-04
# Epoch 73/200
# 24/24 [==============================] - 3s 108ms/step - loss: 6.4703e-04
# Epoch 74/200
# 24/24 [==============================] - 3s 109ms/step - loss: 6.1929e-04
# Epoch 75/200
# 24/24 [==============================] - 3s 109ms/step - loss: 6.2288e-04
# Epoch 76/200
# 24/24 [==============================] - 3s 109ms/step - loss: 7.2155e-04
# Epoch 77/200
# 24/24 [==============================] - 3s 109ms/step - loss: 6.0991e-04
# Epoch 78/200
# 24/24 [==============================] - 3s 108ms/step - loss: 6.0431e-04
# Epoch 79/200
# 24/24 [==============================] - 3s 109ms/step - loss: 8.3635e-04
# Epoch 80/200
# 24/24 [==============================] - 3s 110ms/step - loss: 6.0300e-04
# Epoch 81/200
# 24/24 [==============================] - 3s 109ms/step - loss: 5.8270e-04
# Epoch 82/200
# 24/24 [==============================] - 3s 108ms/step - loss: 5.3691e-04
# Epoch 83/200
# 24/24 [==============================] - 3s 108ms/step - loss: 5.7453e-04
# Epoch 84/200
# 24/24 [==============================] - 3s 109ms/step - loss: 6.6194e-04
# Epoch 85/200
# 24/24 [==============================] - 3s 108ms/step - loss: 5.9909e-04
# Epoch 86/200
# 24/24 [==============================] - 3s 108ms/step - loss: 5.7791e-04
# Epoch 87/200
# 24/24 [==============================] - 3s 109ms/step - loss: 5.3419e-04
# Epoch 88/200
# 24/24 [==============================] - 3s 109ms/step - loss: 5.4107e-04
# Epoch 89/200
# 24/24 [==============================] - 3s 108ms/step - loss: 5.8034e-04
# Epoch 90/200
# 24/24 [==============================] - 3s 109ms/step - loss: 5.3417e-04
# Epoch 91/200
# 24/24 [==============================] - 3s 108ms/step - loss: 4.8254e-04
# Epoch 92/200
# 24/24 [==============================] - 3s 108ms/step - loss: 5.4410e-04
# Epoch 93/200
# 24/24 [==============================] - 3s 109ms/step - loss: 5.3511e-04
# Epoch 94/200
# 24/24 [==============================] - 3s 108ms/step - loss: 5.0617e-04
# Epoch 95/200
# 24/24 [==============================] - 3s 108ms/step - loss: 5.5992e-04
# Epoch 96/200
# 24/24 [==============================] - 3s 111ms/step - loss: 4.8509e-04
# Epoch 97/200
# 24/24 [==============================] - 3s 108ms/step - loss: 4.5609e-04
# Epoch 98/200
# 24/24 [==============================] - 3s 108ms/step - loss: 5.8127e-04
# Epoch 99/200
# 24/24 [==============================] - 3s 110ms/step - loss: 5.5766e-04 0s - loss: 5.5766e-0
# Epoch 100/200
# 24/24 [==============================] - 3s 112ms/step - loss: 5.0289e-04
# Epoch 101/200
# 24/24 [==============================] - 3s 114ms/step - loss: 4.4750e-04
# Epoch 102/200
# 24/24 [==============================] - 3s 109ms/step - loss: 5.2563e-04
# Epoch 103/200
# 24/24 [==============================] - 3s 109ms/step - loss: 8.2871e-04
# Epoch 104/200
# 24/24 [==============================] - 3s 109ms/step - loss: 5.3804e-04
# Epoch 105/200
# 24/24 [==============================] - 3s 109ms/step - loss: 5.7024e-04
# Epoch 106/200
# 24/24 [==============================] - 3s 108ms/step - loss: 4.6531e-04
# Epoch 107/200
# 24/24 [==============================] - 3s 108ms/step - loss: 4.5684e-04
# Epoch 108/200
# 24/24 [==============================] - 3s 108ms/step - loss: 4.5097e-04
# Epoch 109/200
# 24/24 [==============================] - 3s 108ms/step - loss: 4.4944e-04
# Epoch 110/200
# 24/24 [==============================] - 3s 110ms/step - loss: 4.5047e-04
# Epoch 111/200
# 24/24 [==============================] - 3s 110ms/step - loss: 4.2196e-04
# Epoch 112/200
# 24/24 [==============================] - 3s 109ms/step - loss: 4.2860e-04
# Epoch 113/200
# 24/24 [==============================] - 3s 108ms/step - loss: 4.3686e-04
# Epoch 114/200
# 24/24 [==============================] - 3s 108ms/step - loss: 4.8045e-04
# Epoch 115/200
# 24/24 [==============================] - 3s 108ms/step - loss: 5.3505e-04
# Epoch 116/200
# 24/24 [==============================] - 3s 108ms/step - loss: 4.7734e-04
# Epoch 117/200
# 24/24 [==============================] - 3s 109ms/step - loss: 4.4290e-04
# Epoch 118/200
# 24/24 [==============================] - 3s 108ms/step - loss: 4.5159e-04
# Epoch 119/200
# 24/24 [==============================] - 3s 108ms/step - loss: 4.3485e-04
# Epoch 120/200
# 24/24 [==============================] - 3s 108ms/step - loss: 4.2347e-04
# Epoch 121/200
# 24/24 [==============================] - 3s 108ms/step - loss: 5.7057e-04
# Epoch 122/200
# 24/24 [==============================] - 3s 109ms/step - loss: 5.3561e-04
# Epoch 123/200
# 24/24 [==============================] - 3s 108ms/step - loss: 4.4245e-04
# Epoch 124/200
# 24/24 [==============================] - 3s 108ms/step - loss: 4.1601e-04
# Epoch 125/200
# 24/24 [==============================] - 3s 108ms/step - loss: 4.0979e-04
# Epoch 126/200
# 24/24 [==============================] - 3s 109ms/step - loss: 4.5223e-04
# Epoch 127/200
# 24/24 [==============================] - 3s 108ms/step - loss: 4.1551e-04
# Epoch 128/200
# 24/24 [==============================] - 3s 109ms/step - loss: 4.9541e-04
# Epoch 129/200
# 24/24 [==============================] - 3s 108ms/step - loss: 4.3612e-04
# Epoch 130/200
# 24/24 [==============================] - 3s 108ms/step - loss: 4.2059e-04
# Epoch 131/200
# 24/24 [==============================] - 3s 108ms/step - loss: 4.1585e-04
# Epoch 132/200
# 24/24 [==============================] - 3s 109ms/step - loss: 4.0928e-04
# Epoch 133/200
# 24/24 [==============================] - 3s 108ms/step - loss: 4.4558e-04
# Epoch 134/200
# 24/24 [==============================] - 3s 107ms/step - loss: 5.6861e-04
# Epoch 135/200
# 24/24 [==============================] - 3s 108ms/step - loss: 4.0542e-04
# Epoch 136/200
# 24/24 [==============================] - 3s 114ms/step - loss: 4.3182e-04
# Epoch 137/200
# 24/24 [==============================] - 3s 119ms/step - loss: 3.8948e-04
# Epoch 138/200
# 24/24 [==============================] - 3s 111ms/step - loss: 4.2744e-04
# Epoch 139/200
# 24/24 [==============================] - 3s 121ms/step - loss: 4.5729e-04
# Epoch 140/200
# 24/24 [==============================] - 3s 121ms/step - loss: 5.0539e-04
# Epoch 141/200
# 24/24 [==============================] - 3s 117ms/step - loss: 4.5285e-04
# Epoch 142/200
# 24/24 [==============================] - 3s 109ms/step - loss: 3.8832e-04
# Epoch 143/200
# 24/24 [==============================] - 3s 109ms/step - loss: 4.0685e-04
# Epoch 144/200
# 24/24 [==============================] - 3s 109ms/step - loss: 4.3927e-04
# Epoch 145/200
# 24/24 [==============================] - 3s 110ms/step - loss: 4.1208e-04
# Epoch 146/200
# 24/24 [==============================] - 3s 109ms/step - loss: 4.3665e-04
# Epoch 147/200
# 24/24 [==============================] - 3s 109ms/step - loss: 4.6498e-04
# Epoch 148/200
# 24/24 [==============================] - 3s 109ms/step - loss: 4.4720e-04
# Epoch 149/200
# 24/24 [==============================] - 3s 109ms/step - loss: 4.6771e-04
# Epoch 150/200
# 24/24 [==============================] - 3s 108ms/step - loss: 4.2300e-04
# Epoch 151/200
# 24/24 [==============================] - 3s 109ms/step - loss: 4.2946e-04
# Epoch 152/200
# 24/24 [==============================] - 3s 109ms/step - loss: 4.2813e-04
# Epoch 153/200
# 24/24 [==============================] - 3s 109ms/step - loss: 4.3612e-04
# Epoch 154/200
# 24/24 [==============================] - 3s 110ms/step - loss: 4.0317e-04
# Epoch 155/200
# 24/24 [==============================] - 3s 110ms/step - loss: 5.0363e-04
# Epoch 156/200
# 24/24 [==============================] - 3s 109ms/step - loss: 3.9090e-04
# Epoch 157/200
# 24/24 [==============================] - 3s 109ms/step - loss: 4.0280e-04
# Epoch 158/200
# 24/24 [==============================] - 3s 109ms/step - loss: 4.6529e-04
# Epoch 159/200
# 24/24 [==============================] - 3s 109ms/step - loss: 4.4915e-04
# Epoch 160/200
# 24/24 [==============================] - 3s 110ms/step - loss: 4.8726e-04
# Epoch 161/200
# 24/24 [==============================] - 3s 109ms/step - loss: 3.8569e-04
# Epoch 162/200
# 24/24 [==============================] - 3s 110ms/step - loss: 4.0159e-04
# Epoch 163/200
# 24/24 [==============================] - 3s 109ms/step - loss: 4.9468e-04
# Epoch 164/200
# 24/24 [==============================] - 3s 109ms/step - loss: 4.2223e-04
# Epoch 165/200
# 24/24 [==============================] - 3s 109ms/step - loss: 4.0379e-04
# Epoch 166/200
# 24/24 [==============================] - 3s 109ms/step - loss: 4.1899e-04
# Epoch 167/200
# 24/24 [==============================] - 3s 109ms/step - loss: 4.4375e-04
# Epoch 168/200
# 24/24 [==============================] - 3s 110ms/step - loss: 4.4107e-04
# Epoch 169/200
# 24/24 [==============================] - 3s 109ms/step - loss: 4.5280e-04
# Epoch 170/200
# 24/24 [==============================] - 3s 110ms/step - loss: 4.4573e-04
# Epoch 171/200
# 24/24 [==============================] - 3s 109ms/step - loss: 4.7390e-04
# Epoch 172/200
# 24/24 [==============================] - 3s 109ms/step - loss: 4.0339e-04
# Epoch 173/200
# 24/24 [==============================] - 3s 109ms/step - loss: 4.8496e-04
# Epoch 174/200
# 24/24 [==============================] - 3s 110ms/step - loss: 4.3543e-04
# Epoch 175/200
# 24/24 [==============================] - 3s 109ms/step - loss: 4.2199e-04
# Epoch 176/200
# 24/24 [==============================] - 3s 109ms/step - loss: 4.9854e-04
# Epoch 177/200
# 24/24 [==============================] - 3s 109ms/step - loss: 4.2294e-04
# Epoch 178/200
# 24/24 [==============================] - 3s 109ms/step - loss: 4.4664e-04
# Epoch 179/200
# 24/24 [==============================] - 3s 110ms/step - loss: 3.8687e-04
# Epoch 180/200
# 24/24 [==============================] - 3s 108ms/step - loss: 4.1630e-04
# Epoch 181/200
# 24/24 [==============================] - 3s 110ms/step - loss: 4.0220e-04
# Epoch 182/200
# 24/24 [==============================] - 3s 109ms/step - loss: 4.1483e-04
# Epoch 183/200
# 24/24 [==============================] - 3s 110ms/step - loss: 4.1110e-04
# Epoch 184/200
# 24/24 [==============================] - 3s 110ms/step - loss: 4.0088e-04
# Epoch 185/200
# 24/24 [==============================] - 3s 110ms/step - loss: 4.0907e-04
# Epoch 186/200
# 24/24 [==============================] - 3s 109ms/step - loss: 4.3105e-04
# Epoch 187/200
# 24/24 [==============================] - 3s 110ms/step - loss: 3.9138e-04
# Epoch 188/200
# 24/24 [==============================] - 3s 109ms/step - loss: 6.3693e-04
# Epoch 189/200
# 24/24 [==============================] - 3s 109ms/step - loss: 4.5784e-04
# Epoch 190/200
# 24/24 [==============================] - 3s 108ms/step - loss: 4.3088e-04
# Epoch 191/200
# 24/24 [==============================] - 3s 109ms/step - loss: 5.1056e-04
# Epoch 192/200
# 24/24 [==============================] - 3s 109ms/step - loss: 4.3758e-04
# Epoch 193/200
# 24/24 [==============================] - 3s 108ms/step - loss: 4.9476e-04
# Epoch 194/200
# 24/24 [==============================] - 3s 108ms/step - loss: 4.0550e-04
# Epoch 195/200
# 24/24 [==============================] - 3s 108ms/step - loss: 3.9894e-04
# Epoch 196/200
# 24/24 [==============================] - 3s 108ms/step - loss: 4.2762e-04
# Epoch 197/200
# 24/24 [==============================] - 3s 108ms/step - loss: 4.1321e-04
# Epoch 198/200
# 24/24 [==============================] - 3s 109ms/step - loss: 4.0517e-04
# Epoch 199/200
# 24/24 [==============================] - 3s 109ms/step - loss: 4.0232e-04
# Epoch 200/200
# 24/24 [==============================] - 3s 110ms/step - loss: 4.0219e-04
# 0.022907412865691465

# %%
fig, ax = plt.subplots(nrows=1,ncols=1,figsize=(20,10))
ax.plot(y_test,label='Actual Price')
ax.plot(y_hat, c='r', label='Predicted Price')
ax.set_title('ExonMobil Corporation Stock Prediction')
ax.set_ylabel('Stock Price')
ax.set_xlabel('Time')
ax.tick_params(axis='x',
               which='both',
               bottom=False,
               top=False,
               labelbottom=False)
ax.legend()

# %%
def get_forecast(data, model, scaler, history):
    prediction_list = data[-history:]
    data, empty = prep_data(prediction_list, scaler, 1)
    x, y = build_data(data, 10)
    x = np.reshape(x,(x.shape[0],x.shape[1],1))
    forecast = model.predict(x)
    return forecast


history = int(len(y_test)/23)

data = y_test
forecast = get_forecast(data, model, scaler, history)
forecast = fix_data(forecast,scaler)
print(forecast.shape)
forecast = np.concatenate((y_test,forecast))
graph_df = pd.DataFrame(forecast)
# Out:
# (9, 1)

# %%
fig, ax = plt.subplots(nrows=1,ncols=1,figsize=(20,10))

ax.plot(graph_df, label='Recorded Price History')
ax.plot(graph_df.loc[graph_df.index >= len(y_test)], c='r',label='Future Prediction Price')

ax.set_title('ExonMobil Corporation Stock Prediction')
ax.set_ylabel('Stock Price')
ax.set_xlabel('Time (2010-2016)')
ax.tick_params(axis='x',
               which='both',
               bottom=False,
               top=False,
               labelbottom=False)
ax.legend()
