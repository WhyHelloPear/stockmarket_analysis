# %% [markdown]
# # Data Visualization
#
#
# This notebook will be intended to visualize the features present within our dataset. Each graph visualization will be appropriately labeled and will have an attached description to clarify the intent of the graph as well as a short description that details what information was gained.

# %%
import matplotlib.pyplot as plt

import numpy as np
import pandas as pd

# %%
df_fundamentals = pd.read_csv('./data/fundamentals.csv')
df_prices = pd.read_csv('./data/prices.csv')
df_prices_adj = pd.read_csv('./data/prices-split-adjusted.csv')
df_securities = pd.read_csv('./data/securities.csv')

# %%
print(df_fundamentals.shape)
df_fundamentals.head()
# Out:
# (1781, 79)
#    Unnamed: 0 Ticker Symbol Period Ending  Accounts Payable  \
# 0           0           AAL    2012-12-31      3.068000e+09
# 1           1           AAL    2013-12-31      4.975000e+09
# 2           2           AAL    2014-12-31      4.668000e+09
# 3           3           AAL    2015-12-31      5.102000e+09
# 4           4           AAP    2012-12-29      2.409453e+09
#
#    Accounts Receivable  Add'l income/expense items  After Tax ROE  \
# 0         -222000000.0               -1.961000e+09           23.0
# 1          -93000000.0               -2.723000e+09           67.0
# 2         -160000000.0               -1.500000e+08          143.0
# 3          352000000.0               -7.080000e+08          135.0
# 4          -89482000.0                6.000000e+05           32.0
#
#    Capital Expenditures  Capital Surplus  Cash Ratio  ...  \
# 0         -1.888000e+09     4.695000e+09        53.0  ...
# 1         -3.114000e+09     1.059200e+10        75.0  ...
# ...

# %%
print(df_prices.shape)
df_prices.head()
# Out:
# (851264, 7)
#                   date symbol        open       close         low        high  \
# 0  2016-01-05 00:00:00   WLTW  123.430000  125.839996  122.309998  126.250000
# 1  2016-01-06 00:00:00   WLTW  125.239998  119.980003  119.940002  125.540001
# 2  2016-01-07 00:00:00   WLTW  116.379997  114.949997  114.930000  119.739998
# 3  2016-01-08 00:00:00   WLTW  115.480003  116.620003  113.500000  117.440002
# 4  2016-01-11 00:00:00   WLTW  117.010002  114.970001  114.089996  117.330002
#
#       volume
# 0  2163600.0
# 1  2386400.0
# 2  2489500.0
# 3  2006300.0
# 4  1408600.0

# %%
print(df_securities.shape)
df_securities.head()
# Out:
# (505, 8)
#   Ticker symbol             Security SEC filings             GICS Sector  \
# 0           MMM           3M Company     reports             Industrials
# 1           ABT  Abbott Laboratories     reports             Health Care
# 2          ABBV               AbbVie     reports             Health Care
# 3           ACN        Accenture plc     reports  Information Technology
# 4          ATVI  Activision Blizzard     reports  Information Technology
#
#                 GICS Sub Industry   Address of Headquarters Date first added  \
# 0        Industrial Conglomerates       St. Paul, Minnesota              NaN
# 1           Health Care Equipment   North Chicago, Illinois       1964-03-31
# 2                 Pharmaceuticals   North Chicago, Illinois       2012-12-31
# 3  IT Consulting & Other Services           Dublin, Ireland       2011-07-06
# 4     Home Entertainment Software  Santa Monica, California       2015-08-31
#
#        CIK
# 0    66740
# 1     1800
# 2  1551152
# ...

# %% [markdown]
# Below are line-graph visualizations of 5 stocks' prices against time - from 2010 to 2016. We start with Willis Towers' graph.

# %%
# df_prices.groupby('symbol').plot(x='date', y='high')

# %%
df = df_prices.loc[df_prices['symbol'] == 'WLTW']
# df_prices.loc[df_prices['symbol'] == 'WLTW'].plot(x='date', y='low')
df
fig, ax = plt.subplots(nrows=1,ncols=1,figsize=(10,8))
ax.plot(df['date'], df['high'],label='DAILY HIGH')
ax.plot(df['date'], df['low'], c='r', label='DAILY LOW')
ax.set_title('Willis Towers Watson PLC')
ax.set_ylabel('Stock Price')
ax.set_xlabel('Time (2010-2016)')
ax.tick_params(axis='x',
               which='both',
               bottom=False,
               top=False,
               labelbottom=False)
ax.legend()
# ax.show()

# %% [markdown]
# Similarly for the other four stocks:

# %%
stocks ={'AAPL': 'Apple Inc', 'XOM': 'ExonMobil Corporation','AAL': 'American Airlines Group Inc','CVS': 'CVS Health Group'}
for ticker, name in stocks.items():
    df = df_prices.loc[df_prices['symbol'] == ticker]
    # df_prices.loc[df_prices['symbol'] == 'WLTW'].plot(x='date', y='low')
    df
    fig, ax = plt.subplots(nrows=1,ncols=1,figsize=(10,8))
    ax.plot(df['date'], df['high'],label='DAILY HIGH')
    ax.plot(df['date'], df['low'], c='r', label='DAILY LOW')
    ax.set_title(name)
    ax.set_ylabel('Stock Price')
    ax.set_xlabel('Time (2010-2016)')
    ax.tick_params(axis='x',
                   which='both',
                   bottom=False,
                   top=False,
                   labelbottom=False)
    ax.legend()

# %% [markdown]
# Note that the dramatic apparent decrease in Apple's stock price was caused by a 7-1 stock split in 2014.

# %%
#attempting to graph prices from prices.csv against fundamentals such as gross profit. Currently
#showing dimension error
df1 = df_fundamentals.loc[df_fundamentals['Ticker Symbol'] == 'AAPL']
df2 = df_prices.loc[df_prices['symbol']=='AAPL']
df1
df2
fig, ax = plt.subplots(nrows=1,ncols=1,figsize=(10,8))
ax.plot(df1['Gross Profit'], df2['high'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-37-47a4bca9bfd1> in <module>
#       4 df2
#       5 fig, ax = plt.subplots(nrows=1,ncols=1,figsize=(10,8))
# ----> 6 ax.plot(df1['Gross Profit'], df2['high'])
#
# /usr/local/lib/python3.8/site-packages/matplotlib/axes/_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1741         """
#    1742         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1743         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1744         for line in lines:
#    1745             self.add_line(line)
#
# /usr/local/lib/python3.8/site-packages/matplotlib/axes/_base.py in __call__(self, data, *args, **kwargs)
#     271                 this += args[0],
#     272                 args = args[1:]
# --> 273             yield from self._plot_args(this, kwargs)
#     274
# ...

# %% [markdown]
# TODO: Graph fundamentals with high correlation to price for one stock
